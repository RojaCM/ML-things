# %% [markdown]
# <a href="https://colab.research.google.com/github/RojaCM/ML-things/blob/main/Data-analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dict1 ={'Name':['Priyang','Aadhya','Krisha','Vedant','Parshv',
                'Mittal','Archana'],
                'Marks':[98,89,99,87,90,83,99],
                'Gender':['Male','Female','Female','Male','Male',
                         'Female','Female']
               }

# %%
import pandas as pd

# %%
data = pd.DataFrame(dict1)

# %%
data
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female
# 3   Vedant     87    Male
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %%
sum(data['Marks'].between(90,100))
# Out:
# 4

# %%
def marks(x):
  return x/2

# %%
data['Marks'].apply(marks)
# Out:
# 0    49.0
# 1    44.5
# 2    49.5
# 3    43.5
# 4    45.0
# 5    41.5
# 6    49.5
# Name: Marks, dtype: float64

# %%
data['Marks'].apply(lambda x:x/2)
# Out:
# 0    49.0
# 1    44.5
# 2    49.5
# 3    43.5
# 4    45.0
# 5    41.5
# 6    49.5
# Name: Marks, dtype: float64

# %%
data
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female
# 3   Vedant     87    Male
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %%
data['Gender'].map({'Male':0,'Female':1})
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# 4    0
# 5    1
# 6    1
# Name: Gender, dtype: int64

# %%
data=pd.read_csv('/content/Ecommerce Purchases',sep=',')

# %%
data
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
data.shape
# Out:
# (10000, 14)

# %%
data.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %%
data.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
data['Purchase Price'].max()
# Out:
# 99.99

# %%
data['Purchase Price'].min()
# Out:
# 0.0

# %%
data['Purchase Price'].mean()
# Out:
# 50.347302

# %%
data['Language']
# Out:
# 0       el
# 1       fr
# 2       de
# 3       es
# 4       es
#         ..
# 9995    it
# 9996    pt
# 9997    el
# 9998    es
# 9999    el
# Name: Language, Length: 10000, dtype: object

# %%
data[data['Language']=='fr'].reset_index(drop=True)
# Out:
#                                                 Address    Lot AM or PM  \
# 0     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 1                   125 Hall Summit\nBoothton, IL 41721  99 CU       PM
# 2                 PSC 9431, Box 7059\nAPO AA 29285-1363  14 qD       AM
# 3     49206 Campbell Port\nNorth Cliffordshire, HI 3...  71 iu       PM
# 4     493 Smith Valleys Suite 004\nNew Madelineville...  35 ls       PM
# ...                                                 ...    ...      ...
# 1092           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 1093      32827 Carl Inlet\nSouth Nicole, NY 38081-6636  40 Dp       PM
# 1094                518 Brown Dam\nGarciaside, IN 33057  71 wq       AM
# 1095  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 1096           6061 Dave Lights\nPhillipsview, UT 40500  25 Mv       AM
#
#                                            Browser Info  \
# ...

# %%
len(data[data['Language']=='fr'].reset_index(drop=True))
# Out:
# 1097

# %%
data[data['Job'].str.contains('engineer',case=False)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 50      41159 Michael Centers\nAdamsfort, RI 37108-6674  46 Ce       PM
# 55    27635 Maureen Bypass Apt. 883\nSandraview, SD ...  59 LJ       AM
# 60    7126 Katherine Squares\nPerkinsview, CO 97299-...  63 qu       AM
# ...                                                 ...    ...      ...
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9952            9991 Vaughn Hills\nRacheltown, PA 55409  36 KC       PM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %%
data[(data['CC Provider']=='Mastercard') & (data['Purchase Price']>50)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 18    461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 90          431 Bowen Lights\nFergusonborough, MH 01362  31 tG       AM
# ...                                                 ...    ...      ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9954  051 Samantha Wells Apt. 328\nScottborough, OR ...  11 vG       AM
# 9981  087 Larson Roads Apt. 587\nRicestad, WI 98077-...  95 Kw       AM
# 9987     2754 Klein Mission\nJohnsonview, PA 64925-9624  65 Fg       PM
#
#                                            Browser Info  \
# ...

# %%
#Find the email of the person with the following Credit Card Number: 4664825258997302

# %%
data.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
data[data['Credit Card']==4664825258997302]['Email']
# Out:
# 9992    bberry@wright.net
# Name: Email, dtype: object

# %%
#How many people purchase during the AM and how many people purchase during PM?

# %%
data['AM or PM']
# Out:
# 0       PM
# 1       PM
# 2       PM
# 3       PM
# 4       AM
#         ..
# 9995    PM
# 9996    AM
# 9997    AM
# 9998    PM
# 9999    AM
# Name: AM or PM, Length: 10000, dtype: object

# %%
data[data['AM or PM']=='AM']
# Out:
#                                                 Address    Lot AM or PM  \
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 6        93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# 12      733 Heather Rest Apt. 670\nBoltonport, UT 78662  69 DO       AM
# 14    8774 Jason Keys Suite 427\nEast Scottborough, ...  70 zH       AM
# ...                                                 ...    ...      ...
# 9989         5674 Cruz Trace\nNew Shelby, KY 51047-5469  12 Kf       AM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
data[data['AM or PM']=='PM']
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# ...                                                 ...    ...      ...
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
#
#                                            Browser Info  \
# ...

# %%
data['CC Exp Date']
# Out:
# 0       02/20
# 1       11/18
# 2       08/19
# 3       02/24
# 4       10/25
#         ...
# 9995    03/22
# 9996    07/25
# 9997    05/21
# 9998    11/17
# 9999    02/19
# Name: CC Exp Date, Length: 10000, dtype: object

# %%
def fun():
  cnt=0
  for i in data['CC Exp Date']:
    if i.split('/')[1]=='20':
     cnt+=1
  return cnt

# %%
fun()
# Out:
# 988

# %%
data[data['CC Exp Date'].apply(lambda x:x[3:]=='20')].count()
# Out:
# Address             988
# Lot                 988
# AM or PM            988
# Browser Info        988
# Company             988
# Credit Card         988
# CC Exp Date         988
# CC Security Code    988
# CC Provider         988
# Email               988
# Job                 988
# IP Address          988
# Language            988
# Purchase Price      988
# dtype: int64

# %%
data['Email'].apply(lambda x:x.split('@')[1]).value_counts().head()
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64

# %%
l=[]
for email in data['Email']:
  l.append(email.split('@')[1])

# %%
data['temp']=l

# %%
data
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
data['temp'].head()
# Out:
# 0               yahoo.com
# 1                reed.com
# 2    morales-harrison.com
# 3     olson-robinson.info
# 4               gmail.com
# Name: temp, dtype: object

# %%
#3.SALARIES

# %%
import pandas as pd
df=pd.read_csv('Salaries.csv')
# Out:
# <ipython-input-51-85880d0ec06a>:2: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('Salaries.csv')

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#      Year  Notes         Agency  Status
# ...

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df.shape
# Out:
# (97380, 13)

# %%
df.isnull().sum()
# Out:
# Id                      0
# EmployeeName            0
# JobTitle                1
# BasePay                 9
# OvertimePay             1
# OtherPay                1
# Benefits            36160
# TotalPay                1
# TotalPayBenefits        1
# Year                    1
# Notes               97380
# Agency                  1
# Status              97380
# dtype: int64

# %%
df.dtypes
# Out:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay             float64
# OvertimePay         float64
# OtherPay            float64
# Benefits            float64
# TotalPay            float64
# TotalPayBenefits    float64
# Year                float64
# Notes               float64
# Agency               object
# Status              float64
# dtype: object

# %%
df.describe()
# Out:
#                  Id        BasePay    OvertimePay       OtherPay  \
# count  97380.000000   97371.000000   97379.000000   97379.000000
# mean   48690.500000   71901.851540    5540.156950    4044.895668
# std    28111.328944   41211.411676   11941.022553    8539.910138
# min        1.000000    -166.010000      -0.010000   -7058.590000
# 25%    24345.750000   48472.450000       0.000000       0.000000
# 50%    48690.500000   69057.100000      39.260000    1080.000000
# 75%    73035.250000   99014.400000    5563.145000    4881.375000
# max    97380.000000  319275.010000  245131.880000  400184.250000
#
#            Benefits       TotalPay  TotalPayBenefits          Year  Notes  \
# count  61220.000000   97379.000000      97379.000000  97379.000000    0.0
# mean   28984.336214   81480.997188      99702.801304   2011.879800    NaN
# std    13496.092281   48911.396876      60062.465245      0.779745    NaN
# min        0.000000       0.000000          0.000000   2011.000000    NaN
# ...

# %%
df.drop(['Id','Notes','Status'],axis=1,inplace=True)

# %%
df
# Out:
#             EmployeeName                                        JobTitle  \
# 0         NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1           GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2         ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3      CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4        PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                  ...                                             ...
# 97375   Amelie E Bullard                                   Special Nurse
# 97376   Timothy J Stocks                             Food Service Worker
# 97377    Heath  Guillory                                 General Laborer
# 97378        Grace L Dao                                       Custodian
# 97379       Amada U Abul                                             NaN
#
#          BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97380 entries, 0 to 97379
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   EmployeeName      97380 non-null  object
#  1   JobTitle          97379 non-null  object
#  2   BasePay           97371 non-null  float64
#  3   OvertimePay       97379 non-null  float64
#  4   OtherPay          97379 non-null  float64
#  5   Benefits          61220 non-null  float64
#  6   TotalPay          97379 non-null  float64
#  7   TotalPayBenefits  97379 non-null  float64
#  8   Year              97379 non-null  float64
#  9   Agency            97379 non-null  object
# dtypes: float64(7), object(3)
# memory usage: 7.4+ MB

# %%
df['EmployeeName'].value_counts().sort_values(ascending=False).head()
# Out:
# KEVIN LEE      9
# Kevin Lee      9
# MICHAEL LEE    8
# RICHARD LEE    8
# DAVID WONG     8
# Name: EmployeeName, dtype: int64

# %%
# Find The Number of Unique Job Titles

df['JobTitle'].nunique()
# Out:
# 2113

# %%
#Total Number of Job Titles Contain Captain
df[df['JobTitle'].str.contains('captain',case=False)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-b831757e98c9> in <cell line: 2>()
#       1 #Total Number of Job Titles Contain Captain
# ----> 2 df[df['JobTitle'].str.contains('captain',case=False)]
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3795
#    3796         # Do we have a (boolean) 1d indexer?
# -> 3797         if com.is_bool_indexer(key):
#    3798             return self._getitem_bool_array(key)
#    3799
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/common.py in is_bool_indexer(key)
#     133                     # Don't raise on e.g. ["A", "B", np.nan], see
#     134                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 135                     raise ValueError(na_msg)
#     136                 return False
#     137             return True
#
# ...

# %%
#Display All the Employee Names From Fire Department
df[df['JobTitle'].str.contains('FIRE DEPARTMENT',case=False)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-9e18559154ab> in <cell line: 2>()
#       1 #Display All the Employee Names From Fire Department
# ----> 2 df[df['JobTitle'].str.contains('FIRE DEPARTMENT',case=False)]
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3795
#    3796         # Do we have a (boolean) 1d indexer?
# -> 3797         if com.is_bool_indexer(key):
#    3798             return self._getitem_bool_array(key)
#    3799
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/common.py in is_bool_indexer(key)
#     133                     # Don't raise on e.g. ["A", "B", np.nan], see
#     134                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 135                     raise ValueError(na_msg)
#     136                 return False
#     137             return True
# ...

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Agency'],
#       dtype='object')

# %%
df['BasePay'].mean()
# Out:
# 71901.85153998624

# %%
df['BasePay'].max()
# Out:
# 319275.01

# %%
df['BasePay'].min()
# Out:
# -166.01

# %%
import numpy as np
df['EmployeeName']=df['EmployeeName'].map({'Not provided':np.nan})

# %%
df
# Out:
#        EmployeeName                                        JobTitle  \
# 0               NaN  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1               NaN                 CAPTAIN III (POLICE DEPARTMENT)
# 2               NaN                 CAPTAIN III (POLICE DEPARTMENT)
# 3               NaN            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4               NaN    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...             ...                                             ...
# 97375           NaN                                   Special Nurse
# 97376           NaN                             Food Service Worker
# 97377           NaN                                 General Laborer
# 97378           NaN                                       Custodian
# 97379           NaN                                             NaN
#
#          BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# 0      167411.18         0.00  400184.25       NaN  567595.43
# ...

# %%
df[df.isnull().sum(axis=1)==5]
# Out:
# Empty DataFrame
# Columns: [EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year, Agency]
# Index: []

# %%
df[df['EmployeeName']=='ALBERT PARDINI']['JobTitle']
# Out:
# 2    CAPTAIN III (POLICE DEPARTMENT)
# Name: JobTitle, dtype: object

# %%
df.shape
# Out:
# (148654, 13)

# %%
df['BasePay'].min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-894fe199e92c> in <cell line: 1>()
# ----> 1 df['BasePay'].min()
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in min(self, axis, skipna, level, numeric_only, **kwargs)
#   11963             **kwargs,
#   11964         ):
# > 11965             return NDFrame.min(self, axis, skipna, level, numeric_only, **kwargs)
#   11966
#   11967         setattr(cls, "min", min)
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in min(self, axis, skipna, level, numeric_only, **kwargs)
#   11363         **kwargs,
#   11364     ):
# > 11365         return self._stat_function(
#   11366             "min",
#   11367             nanops.nanmin,
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
# ...
