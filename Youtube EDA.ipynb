# %% [markdown]
# <a href="https://colab.research.google.com/github/RojaCM/ML-things/blob/main/Youtube%20EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv('top-5000-youtube-channels.csv')

# %%
data.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
data.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views'],
#       dtype='object')

# %%
data.shape
# Out:
# (5000, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5000 non-null   object
#  1   Grade          5000 non-null   object
#  2   Channel name   5000 non-null   object
#  3   Video Uploads  5000 non-null   object
#  4   Subscribers    5000 non-null   object
#  5   Video views    5000 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB

# %% [markdown]
# 1. Display All Rows Except the Last 5 rows Using Head Method
# 2. Display All Rows Except the First 5 Rows Using Tail Method
# 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)
# 4. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement
# 5. Get Overall Statistics About The Dataframe
# 6. Data Cleaning  (Replace '--'  to NaN)
# 7. Check Null Values In The Dataset
# 8. Data Cleaning [ Rank Column ]
# 9. Data Cleaning [ Video Uploads & Subscribers ]
# 10. Data Cleaning [ Grade Column ]
# 11. Find Average Views For Each Channel
# 12. Find Out Top Five Channels With Maximum Number of Video Uploads
# 13. Find Correlation Matrix
# 14.  Which Grade Has A Maximum Number of Video Uploads?
# 15.Which Grade Has The Highest Average Views?
# 16.  Which Grade Has The Highest Number of Subscribers?
# 17. Which Grade Has The Highest Video Views?

# %%
data.describe(include='all')
# Out:
#         Rank Grade Channel name Video Uploads Subscribers   Video views
# count   5000  5000         5000          5000        5000  5.000000e+03
# unique  5000     6         4993          2286        4612           NaN
# top      1st   B+    Thơ Nguyễn            26         --            NaN
# freq       1  2956            2            17         387           NaN
# mean     NaN   NaN          NaN           NaN         NaN  1.071449e+09
# std      NaN   NaN          NaN           NaN         NaN  2.003844e+09
# min      NaN   NaN          NaN           NaN         NaN  7.500000e+01
# 25%      NaN   NaN          NaN           NaN         NaN  1.862329e+08
# 50%      NaN   NaN          NaN           NaN         NaN  4.820548e+08
# 75%      NaN   NaN          NaN           NaN         NaN  1.124368e+09
# max      NaN   NaN          NaN           NaN         NaN  4.754884e+10

# %%
data.head(4995)
# Out:
#          Rank Grade                      Channel name Video Uploads  \
# 0         1st  A++                             Zee TV         82757
# 1         2nd  A++                           T-Series         12661
# 2         3rd  A++         Cocomelon - Nursery Rhymes           373
# 3         4th  A++                          SET India         27323
# 4         5th  A++                                WWE         36756
# ...       ...   ...                               ...           ...
# 4990  4,991st   B+      Ho Ngoc Ha's Official Channel           208
# 4991  4,992nd   B+               Toys to Learn Colors            11
# 4992  4,993rd   B+                              КАZКА            25
# 4993  4,994th   B+   United CUBE (CUBE Entertainment…          1055
# 4994  4,995th   B+                      Wings Marathi          1735
#
#      Subscribers  Video views
# 0       18752951  20869786591
# 1       61196302  47548839843
# 2       19238251   9793305082
# ...

# %%
data.head(-5)
# Out:
#          Rank Grade                      Channel name Video Uploads  \
# 0         1st  A++                             Zee TV         82757
# 1         2nd  A++                           T-Series         12661
# 2         3rd  A++         Cocomelon - Nursery Rhymes           373
# 3         4th  A++                          SET India         27323
# 4         5th  A++                                WWE         36756
# ...       ...   ...                               ...           ...
# 4990  4,991st   B+      Ho Ngoc Ha's Official Channel           208
# 4991  4,992nd   B+               Toys to Learn Colors            11
# 4992  4,993rd   B+                              КАZКА            25
# 4993  4,994th   B+   United CUBE (CUBE Entertainment…          1055
# 4994  4,995th   B+                      Wings Marathi          1735
#
#      Subscribers  Video views
# 0       18752951  20869786591
# 1       61196302  47548839843
# 2       19238251   9793305082
# ...

# %%
data.tail(-5)
# Out:
#          Rank Grade           Channel name Video Uploads Subscribers  \
# 5         6th  A++              Movieclips         30243    17149705
# 6         7th  A++              netd müzik          8500    11373567
# 7         8th  A++   ABS-CBN Entertainment        100147    12149206
# 8         9th  A++         Ryan ToysReview          1140    16082927
# 9        10th  A++             Zee Marathi         74607     2841811
# ...       ...   ...                    ...           ...         ...
# 4995  4,996th   B+          Uras Benlioğlu           706     2072942
# 4996  4,997th   B+       HI-TECH MUSIC LTD           797     1055091
# 4997  4,998th   B+             Mastersaint           110     3265735
# 4998  4,999th   B+          Bruce McIntosh          3475       32990
# 4999  5,000th   B+               SehatAQUA           254       21172
#
#       Video views
# 5     16618094724
# 6     23898730764
# 7     17202609850
# 8     24518098041
# 9      2591830307
# ...           ...
# ...

# %%
data.isnull().sum()
# Out:
# Rank             0
# Grade            0
# Channel name     0
# Video Uploads    0
# Subscribers      0
# Video views      0
# dtype: int64

# %%
data1=data.copy()

# %%
data.
# Out:
#          Rank Grade                Channel name Video Uploads Subscribers  \
# 0         1st  A++                       Zee TV         82757    18752951
# 1         2nd  A++                     T-Series         12661    61196302
# 2         3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3         4th  A++                    SET India         27323    31180559
# 4         5th  A++                          WWE         36756    32852346
# ...       ...   ...                         ...           ...         ...
# 4995  4,996th   B+               Uras Benlioğlu           706     2072942
# 4996  4,997th   B+            HI-TECH MUSIC LTD           797     1055091
# 4997  4,998th   B+                  Mastersaint           110     3265735
# 4998  4,999th   B+               Bruce McIntosh          3475       32990
# 4999  5,000th   B+                    SehatAQUA           254       21172
#
#       Video views
# 0     20869786591
# 1     47548839843
# 2      9793305082
# ...

# %%
pd.options.display.float_format='{:.2f}'.format

# %%
data.describe()
# Out:
#          Video views
# count        5000.00
# mean   1071449400.15
# std    2003843972.12
# min            75.00
# 25%     186232945.75
# 50%     482054780.00
# 75%    1124367826.75
# max   47548839843.00

# %%
import numpy as np

# %%
data=data.replace('--',np.nan)

# %%
data.isnull().sum()
# Out:
# Rank             0
# Grade            0
# Channel name     0
# Video Uploads    6
# Subscribers      0
# Video views      0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data.dropna(axis=0,inplace=True)

# %%
data.isnull().sum()
# Out:
# Rank             0
# Grade            0
# Channel name     0
# Video Uploads    0
# Subscribers      0
# Video views      0
# dtype: int64

# %%
data.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
data['Rank'].nunique()
# Out:
# 4994

# %%
data.tail()
# Out:
#          Rank Grade       Channel name Video Uploads Subscribers  Video views
# 4995  4,996th   B+      Uras Benlioğlu           706     2072942    441202795
# 4996  4,997th   B+   HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4,998th   B+         Mastersaint           110     3265735    311758426
# 4998  4,999th   B+      Bruce McIntosh          3475       32990     14563764
# 4999  5,000th   B+           SehatAQUA           254       21172     73312511

# %%
data['Rank']=data['Rank'].str.replace(',','')

# %%
data.tail()
# Out:
#         Rank Grade       Channel name Video Uploads Subscribers  Video views
# 4995  4996th   B+      Uras Benlioğlu           706     2072942    441202795
# 4996  4997th   B+   HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4998th   B+         Mastersaint           110     3265735    311758426
# 4998  4999th   B+      Bruce McIntosh          3475       32990     14563764
# 4999  5000th   B+           SehatAQUA           254       21172     73312511

# %%
data['Rank']=data['Rank'].str.replace('th','')

# %%
data
# Out:
#       Rank Grade                Channel name Video Uploads Subscribers  \
# 0      1st  A++                       Zee TV         82757    18752951
# 1      2nd  A++                     T-Series         12661    61196302
# 2      3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3        4  A++                    SET India         27323    31180559
# 4        5  A++                          WWE         36756    32852346
# ...    ...   ...                         ...           ...         ...
# 4995  4996   B+               Uras Benlioğlu           706     2072942
# 4996  4997   B+            HI-TECH MUSIC LTD           797     1055091
# 4997  4998   B+                  Mastersaint           110     3265735
# 4998  4999   B+               Bruce McIntosh          3475       32990
# 4999  5000   B+                    SehatAQUA           254       21172
#
#       Video views
# 0     20869786591
# 1     47548839843
# 2      9793305082
# 3     22675948293
# ...

# %%
data['Rank']=data['Rank'].str.replace('st','')

# %%
data['Rank']=data['Rank'].str.replace('nd','')

# %%
data['Rank']=data['Rank'].str.replace('rd','')

# %%
data['Rank']=data['Rank'].astype('int')

# %%
data.dtypes
# Out:
# Rank              int64
# Grade            object
# Channel name     object
# Video Uploads    object
# Subscribers      object
# Video views       int64
# dtype: object

# %%
data['Video Uploads']=data['Video Uploads'].astype('int')

# %%
data['Subscribers']=data['Subscribers'].astype('int')

# %%
data=data.replace('-- ',np.nan)

# %%
data.isnull().sum()
# Out:
# Rank               0
# Grade              0
# Channel name       0
# Video Uploads      0
# Subscribers      384
# Video views        0
# dtype: int64

# %%
data.dropna(axis=0,inplace=True)

# %%
data.head()
# Out:
#    Rank Grade                Channel name  Video Uploads  Subscribers  \
# 0     1  A++                       Zee TV          82757     18752951
# 1     2  A++                     T-Series          12661     61196302
# 2     3  A++   Cocomelon - Nursery Rhymes            373     19238251
# 3     4  A++                    SET India          27323     31180559
# 4     5  A++                          WWE          36756     32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
data['Grade'].value_counts()
# Out:
# B+      2722
# A-       941
# A        897
# A+        40
# A++       10
# Name: Grade, dtype: int64

# %%
data['Grade']=data['Grade'].map({'A++ ':5,'A+ ':4,'A ':3,'A- ':2,'B+ ':1})

# %%
data.dtypes
# Out:
# Rank              int64
# Grade             int64
# Channel name     object
# Video Uploads     int64
# Subscribers       int64
# Video views       int64
# dtype: object

# %%
data['Video views'].mean()
# Out:
# 1138403081.178959

# %%
data.drop('Video views',inplace=True,axis=1)

# %%
data['Video views']=data1['Video views']

# %%
#Find Out Top Five Channels With Maximum Number of Video Uploads
data.groupby('Channel name')['Video Uploads'].max().sort_values(ascending=False).head()
# Out:
# Channel name
# AP Archive    422326
# YTN NEWS      355996
# SBS Drama     335521
# GMA News      269065
# MLB           267649
# Name: Video Uploads, dtype: int64

# %%
data['Video Uploads'].sort_values(ascending=False)
# Out:
# 3453    422326
# 1149    355996
# 2223    335521
# 323     269065
# 2956    267649
#          ...
# 4100         1
# 2404         1
# 4474         1
# 628          1
# 4975         1
# Name: Video Uploads, Length: 4610, dtype: int64

# %%
data.corr()
# Out:
# <ipython-input-76-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                Rank  Grade  Video Uploads  Subscribers  Video views
# Rank           1.00  -0.87          -0.07        -0.38        -0.40
# Grade         -0.87   1.00           0.09         0.43         0.48
# Video Uploads -0.07   0.09           1.00         0.01         0.09
# Subscribers   -0.38   0.43           0.01         1.00         0.79
# Video views   -0.40   0.48           0.09         0.79         1.00

# %%
data['Grade'].nunique()
# Out:
# 5

# %%
data['Grade'].value_counts()
# Out:
# 1    2722
# 2     941
# 3     897
# 4      40
# 5      10
# Name: Grade, dtype: int64

# %%
data.groupby('Grade')['Video Uploads'].max()
# Out:
# Grade
# 1    422326
# 2    355996
# 3    269065
# 4    186194
# 5    100147
# Name: Video Uploads, dtype: int64

# %%
sns.barplot(x='Grade',y='Video Uploads',data=data)
# Out:
# <Axes: xlabel='Grade', ylabel='Video Uploads'>

# %%
sns.barplot(x='Grade',y='Video views',data=data)
# Out:
# <Axes: xlabel='Grade', ylabel='Video views'>

# %%
sns.barplot(x='Grade',y='Subscribers',data=data)
# Out:
# <Axes: xlabel='Grade', ylabel='Subscribers'>
