# %% [markdown]
# <a href="https://colab.research.google.com/github/RojaCM/ML-things/blob/main/Udemy_courses.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://www.kaggle.com/datasets/andrewmvd/udemy-courses

# %%
import pandas as pd

# %%
df=pd.read_csv('udemy_courses.csv')

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df.dtypes
# Out:
# course_id                int64
# course_title            object
# url                     object
# is_paid                   bool
# price                    int64
# num_subscribers          int64
# num_reviews              int64
# num_lectures             int64
# level                   object
# content_duration       float64
# published_timestamp     object
# subject                 object
# dtype: object

# %%
df1=pd.read_csv('udemy_courses.csv',parse_dates=['published_timestamp'])

# %%
df1.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
df1.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df1.head(10)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
# 5     192870  Trading Penny Stocks: A Guide for All Levels I...
# 6     739964  Investing And Trading For Beginners: Mastering...
# 7     403100  Trading Stock Chart Patterns For Immediate, Ex...
# 8     476268  Options Trading 3 : Advanced Stock Profit and ...
# 9    1167710  The Only Investment Strategy You Need For Your...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# ...

# %%
df1.sample(frac=0.5)
# Out:
#       course_id                                       course_title  \
# 364      419308                                    TRADING TACTICS
# 1009     479496                           Basic Technical Analysis
# 782     1221942                                  Basic Bookkeeping
# 635     1149564            The Forex Pivot Points Trading Strategy
# 3199    1241254  AWS Serverless APIs & Apps - A Complete Introd...
# ...         ...                                                ...
# 2389     794398                Make Electronic Music with the iPad
# 3435     505780  How to Register a Domain, Set Up Hosting, and ...
# 2968     442504      Build an HTML5 and CSS3 Website in 35 Minutes
# 1955    1002272                     Blues Bass - Quick Start Guide
# 924     1056242                      Practical Accounts Training A
#
#                                                     url  is_paid  price  \
# 364              https://www.udemy.com/trading-tactics/     True    145
# ...

# %%
df1.shape
# Out:
# (3678, 12)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   datetime64[ns, UTC]
#  11  subject              3678 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(5), object(4)
# memory usage: 319.8+ KB

# %%
df1.describe()
# Out:
#           course_id        price  num_subscribers   num_reviews  num_lectures  \
# count  3.678000e+03  3678.000000      3678.000000   3678.000000   3678.000000
# mean   6.759720e+05    66.049483      3197.150625    156.259108     40.108755
# std    3.432732e+05    61.005755      9504.117010    935.452044     50.383346
# min    8.324000e+03     0.000000         0.000000      0.000000      0.000000
# 25%    4.076925e+05    20.000000       111.000000      4.000000     15.000000
# 50%    6.879170e+05    45.000000       911.500000     18.000000     25.000000
# 75%    9.613555e+05    95.000000      2546.000000     67.000000     45.750000
# max    1.282064e+06   200.000000    268923.000000  27445.000000    779.000000
#
#        content_duration
# count       3678.000000
# mean           4.094517
# std            6.053840
# min            0.000000
# 25%            1.000000
# 50%            2.000000
# 75%            4.500000
# max           78.500000

# %%
df1.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
df1.duplicated().any()
# Out:
# True

# %%
df2=df1.copy()

# %%
df1.drop_duplicates(inplace=True)

# %%
df1.duplicated().any()
# Out:
# False

# %%
import seaborn as sns

# %%
sns.heatmap(df1.isnull())
# Out:
# <Axes: >

# %%
#Find Out Number of Courses Per Subjects
df1['subject'].value_counts()
# Out:
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: subject, dtype: int64

# %%
df1.groupby('subject')['course_title'].count()
# Out:
# subject
# Business Finance       1191
# Graphic Design          602
# Musical Instruments     680
# Web Development        1199
# Name: course_title, dtype: int64

# %%
df1.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
# For Which Levels, Udemy Courses Providing The Courses
sns.barplot(x=df1['subject'],y=df1['subject'].value_counts(),data=df1)
# Out:
# <Axes: xlabel='subject', ylabel='subject'>

# %%
df3=df2.copy()

# %%
df1['level'].value_counts()
# Out:
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: level, dtype: int64

# %%
#Display The Count of Paid and Free Courses

# %%
df1['is_paid'].value_counts()
# Out:
# True     3362
# False     310
# Name: is_paid, dtype: int64

# %%
#Which Course Has More Lectures (Free or Paid)?
df1.groupby('is_paid')['num_lectures'].sum()
# Out:
# is_paid
# False      6639
# True     140756
# Name: num_lectures, dtype: int64

# %%
df1.groupby('is_paid').mean()
# Out:
# <ipython-input-54-41709483e665>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1.groupby('is_paid').mean()
#              course_id      price  num_subscribers  num_reviews  num_lectures  \
# is_paid
# False    691446.970968   0.000000     11533.951613   425.929032     21.416129
# True     674463.946163  72.198096      2421.270077   131.516359     41.866746
#
#          content_duration
# is_paid
# False            2.210753
# True             4.271584

# %%
#which Courses Have A Higher Number of Subscribers Free or Paid?
df1.groupby('is_paid').mean()
# Out:
# <ipython-input-56-af38eeecba45>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1.groupby('is_paid').mean()
#              course_id      price  num_subscribers  num_reviews  num_lectures  \
# is_paid
# False    691446.970968   0.000000     11533.951613   425.929032     21.416129
# True     674463.946163  72.198096      2421.270077   131.516359     41.866746
#
#          content_duration
# is_paid
# False            2.210753
# True             4.271584

# %%
#Which Level Has The Highest Number of Subscribers?
df1.groupby('level')['num_subscribers'].count()
# Out:
# level
# All Levels            1925
# Beginner Level        1268
# Expert Level            58
# Intermediate Level     421
# Name: num_subscribers, dtype: int64

# %%
#find the most popular course title

# %%
df1['course_title'].mode()
# Out:
# 0                        Acoustic Blues Guitar Lessons
# 1    Creating an animated greeting card via Google ...
# Name: course_title, dtype: object

# %%
df1[df1['num_subscribers'].max()==df1['num_subscribers']]
# Out:
#       course_id                          course_title  \
# 2827      41295  Learn HTML5 Programming From Scratch
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
#
#       num_subscribers  num_reviews  num_lectures       level  \
# 2827           268923         8629            45  All Levels
#
#       content_duration       published_timestamp          subject
# 2827              10.5 2013-02-14 07:03:41+00:00  Web Development

# %%
df1[df1['num_subscribers'].max()==df1['num_subscribers']]['course_title']
# Out:
# 2827    Learn HTML5 Programming From Scratch
# Name: course_title, dtype: object

# %%
#Display 10 Most Popular Courses As Per Number of Subscribers
top_10=df1.groupby('course_title')['num_subscribers'].max().sort_values(ascending=False).head(10)

# %%
top=df1.sort_values(by='num_subscribers',ascending=False).head(10)

# %%
import matplotlib.pyplot as plt
sns.barplot(x='num_subscribers',y='course_title',data=top)
plt.show()

# %%
top_10
# Out:
# course_title
# Learn HTML5 Programming From Scratch                          268923
# Coding for Entrepreneurs Basic                                161029
# The Web Developer Bootcamp                                    121584
# Build Your First Website in 1 Week with HTML5 and CSS3        120291
# The Complete Web Developer Course 2.0                         114512
# Free Beginner Electric Guitar Lessons                         101154
# Web Design for Web Developers: Build Beautiful Websites!       98867
# Learn Javascript & JQuery From Scratch                         84897
# Practical PHP: Master the Basics and Code Dynamic Websites     83737
# JavaScript: Understanding the Weird Parts                      79612
# Name: num_subscribers, dtype: int64

# %%
#Find The Course Which Is Having The Highest Number of Reviews.
df1.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df1[df1['num_reviews'].max()==df1['num_reviews']]['course_title']
# Out:
# 3230    The Web Developer Bootcamp
# Name: course_title, dtype: object

# %%
# Does Price Affect the Number of Reviews?
sns.scatterplot(x='price',y='num_reviews',data=df)
# Out:
# <Axes: xlabel='price', ylabel='num_reviews'>

# %%
#Find Total Number of Courses Related To Python
df1[df1['course_title'].str.contains('python',case=False)]
# Out:
#       course_id                                       course_title  \
# 14      1196544   Python Algo Trading: Sentiment Trading with News
# 30      1170894  Python Algo Stock Trading: Automate Your Trading!
# 41      1035472  Python for Finance: Investment Fundamentals & ...
# 147     1070886         Python Algo Trading: FX Trading with Oanda
# 334      815482               Stock Technical Analysis with Python
# 536      529828                     Python for Trading & Investing
# 762     1088656          Quantitative Trading Analysis with Python
# 863      902888          Investment Portfolio Analysis with Python
# 1682     546848  Learn to code in Python and learn Adobe Photos...
# 2497      16646                        Web Programming with Python
# 2528     391546        Learn Python and Django: Payment Processing
# 2553     938560  The Complete Ethical Hacking Course 2.0: Pytho...
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...
# ...

# %%
#Display 10 Most Popular Python Courses As Per Number of Subscribers
a=df1[df1['course_title'].str.contains('python',case=False)].sort_values(by='num_subscribers',ascending=False).head(10)
a
# Out:
#       course_id                                       course_title  \
# 2497      16646                        Web Programming with Python
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...
# 2528     391546        Learn Python and Django: Payment Processing
# 3200     822444  Python and Django Full Stack Web Developer Boo...
# 3507     394832  Fun and creative web engineering with Python a...
# 2553     938560  The Complete Ethical Hacking Course 2.0: Pytho...
# 3138     631128  Complete Python Web Course: Build 8 Python Web...
# 3197      76052  Try Django 1.9 | Build a Blog and Learn Python...
# 2681     477702  Python for Beginners: Python Programming Langu...
# 3203     970600                    REST APIs with Flask and Python
#
#                                                     url  is_paid  price  \
# 2497  https://www.udemy.com/web-programming-with-pyt...     True     50
# 2570    https://www.udemy.com/coding-for-entrepreneurs/     True    195
# ...

# %%
a.index
# Out:
# Int64Index([2497, 2570, 2528, 3200, 3507, 2553, 3138, 3197, 2681, 3203], dtype='int64')

# %%
df1.loc[[2497, 2570, 2528, 3200, 3507, 2553, 3138, 3197, 2681, 3203],'course_title']
# Out:
# 2497                          Web Programming with Python
# 2570    Coding for Entrepreneurs: Learn Python, Django...
# 2528          Learn Python and Django: Payment Processing
# 3200    Python and Django Full Stack Web Developer Boo...
# 3507    Fun and creative web engineering with Python a...
# 2553    The Complete Ethical Hacking Course 2.0: Pytho...
# 3138    Complete Python Web Course: Build 8 Python Web...
# 3197    Try Django 1.9 | Build a Blog and Learn Python...
# 2681    Python for Beginners: Python Programming Langu...
# 3203                      REST APIs with Flask and Python
# Name: course_title, dtype: object

# %%
sns.barplot(x='num_subscribers',y='course_title',data=a)
# Out:
# <Axes: xlabel='num_subscribers', ylabel='course_title'>

# %%
#In Which Year The Highest Number of Courses Were Posted?

# %%
df1.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df1['year']=df1['published_timestamp'].dt.year

# %%
df1
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
df1.groupby('year')['course_title'].count().sort_values(ascending=False)
# Out:
# year
# 2016    1204
# 2015    1014
# 2017     713
# 2014     490
# 2013     201
# 2012      45
# 2011       5
# Name: course_title, dtype: int64

# %%
#Display Category-Wise Count of Posted Subjects [Year Wise]

# %%
df1.groupby('year')['subject'].value_counts()
# Out:
# year  subject
# 2011  Web Development          5
# 2012  Web Development         19
#       Graphic Design          10
#       Musical Instruments     10
#       Business Finance         6
# 2013  Business Finance        84
#       Web Development         55
#       Musical Instruments     39
#       Graphic Design          23
# 2014  Business Finance       192
#       Musical Instruments    120
#       Web Development        113
#       Graphic Design          65
# 2015  Business Finance       339
#       Web Development        336
#       Musical Instruments    171
#       Graphic Design         168
# 2016  Web Development        448
#       Business Finance       347
#       Musical Instruments    228
#       Graphic Design         181
# 2017  Business Finance       223
#       Web Development        223
#       Graphic Design         155
#       Musical Instruments    112
# Name: subject, dtype: int64
