# %% [markdown]
# <a href="https://colab.research.google.com/github/RojaCM/ML-things/blob/main/Data%20Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv('adult.csv')

# %%
data.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male           0.0           0.0
# 1    Farming-fishing      Husband  White    Male           0.0           0.0
# 2    Protective-serv      Husband  White    Male           0.0           0.0
# 3  Machine-op-inspct      Husband  Black    Male        7688.0           0.0
# 4                  ?    Own-child  White  Female           0.0           0.0
#
#    hours-per-week native-country income
# ...

# %%
#How to fetch random samples from the Dataset?
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28855 entries, 0 to 28854
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              28855 non-null  int64
#  1   workclass        28855 non-null  object
#  2   fnlwgt           28855 non-null  int64
#  3   education        28855 non-null  object
#  4   educational-num  28855 non-null  int64
#  5   marital-status   28855 non-null  object
#  6   occupation       28854 non-null  object
#  7   relationship     28854 non-null  object
#  8   race             28854 non-null  object
#  9   gender           28854 non-null  object
#  10  capital-gain     28854 non-null  float64
#  11  capital-loss     28854 non-null  float64
#  12  hours-per-week   28854 non-null  float64
#  13  native-country   28854 non-null  object
#  14  income           28854 non-null  object
# dtypes: float64(3), int64(3), object(9)
# memory usage: 3.3+ MB

# %%
data.shape
# Out:
# (28855, 15)

# %%
data.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  28855.000000  2.885500e+04     28855.000000  28854.000000
# mean      38.634344  1.897565e+05        10.073575   1070.827892
# std       13.742880  1.054501e+05         2.559413   7463.025745
# min       17.000000  1.349200e+04         1.000000      0.000000
# 25%       28.000000  1.175270e+05         9.000000      0.000000
# 50%       37.000000  1.781090e+05        10.000000      0.000000
# 75%       48.000000  2.384100e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  28854.000000    28854.000000
# mean      88.328273       40.442608
# std      403.260391       12.384877
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
data.sample(frac=0.5)
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 12086   47           Private  138069  Some-college               10
# 2252    30           Private  181212  Some-college               10
# 18171   68  Self-emp-not-inc  197015       HS-grad                9
# 21952   32           Private  216361  Some-college               10
# 10890   40                 ?  438427    Assoc-acdm               12
# ...    ...               ...     ...           ...              ...
# 9735    71                 ?   78786       7th-8th                4
# 14616   22           Private  293136  Some-college               10
# 21728   20           Private   89991  Some-college               10
# 2172    39      Self-emp-inc  210610   Prof-school               15
# 1159    24           Private   70261  Some-college               10
#
#            marital-status        occupation    relationship   race  gender  \
# ...

# %%
data.sample(frac=0.5,random_state=111)
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 25442   39           Private  175972  Some-college               10
# 21463   25           Private  218667       5th-6th                3
# 7791    50           Private   46401     Bachelors               13
# 27253   37           Private  127961       HS-grad                9
# 17804   20           Private  170800  Some-college               10
# ...    ...               ...     ...           ...              ...
# 1108    52           Private   88073     Bachelors               13
# 9009    46           Private  186256  Some-college               10
# 26721   19                 ?  252292       HS-grad                9
# 7914    64         State-gov  186376     Bachelors               13
# 19822   39  Self-emp-not-inc  188571     Assoc-voc               11
#
#               marital-status         occupation   relationship   race  gender  \
# ...

# %%
data.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         1
# relationship       1
# race               1
# gender             1
# capital-gain       1
# capital-loss       1
# hours-per-week     1
# native-country     1
# income             1
# dtype: int64

# %%
import numpy as np
np.round(data.isnull().sum()/data.shape[0],2)
# Out:
# age                0.0
# workclass          0.0
# fnlwgt             0.0
# education          0.0
# educational-num    0.0
# marital-status     0.0
# occupation         0.0
# relationship       0.0
# race               0.0
# gender             0.0
# capital-gain       0.0
# capital-loss       0.0
# hours-per-week     0.0
# native-country     0.0
# income             0.0
# dtype: float64

# %%
#column wise
data.isnull().sum(axis=0)
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         1
# relationship       1
# race               1
# gender             1
# capital-gain       1
# capital-loss       1
# hours-per-week     1
# native-country     1
# income             1
# dtype: int64

# %%
#row wise
data.isnull().sum(axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 28850    0
# 28851    0
# 28852    0
# 28853    0
# 28854    9
# Length: 28855, dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data.tail(3)
# Out:
#        age workclass  fnlwgt  education  educational-num      marital-status  \
# 28852   29   Private  108574  Assoc-voc               11       Never-married
# 28853   56   Private  244605    HS-grad                9  Married-civ-spouse
# 28854   45   Private  363677  Doctorate               16                  Ma
#
#             occupation relationship   race  gender  capital-gain  \
# 28852  Priv-house-serv    Own-child  White  Female           0.0
# 28853     Craft-repair      Husband  White    Male           0.0
# 28854              NaN          NaN    NaN     NaN           NaN
#
#        capital-loss  hours-per-week native-country income
# 28852           0.0            40.0  United-States  <=50K
# 28853           0.0            40.0  United-States  <=50K
# 28854           NaN             NaN            NaN    NaN

# %%
data.isin(['?']).sum()
# Out:
# age                   0
# workclass          1695
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         1700
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      497
# income                0
# dtype: int64

# %%
data2=data.copy()

# %%
data.replace('?',np.nan)
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 0       25    Private  226802          11th                7
# 1       38    Private   89814       HS-grad                9
# 2       28  Local-gov  336951    Assoc-acdm               12
# 3       44    Private  160323  Some-college               10
# 4       18        NaN  103497  Some-college               10
# ...    ...        ...     ...           ...              ...
# 28850   25    Private   66935       HS-grad                9
# 28851   20    Private  344278          11th                7
# 28852   29    Private  108574     Assoc-voc               11
# 28853   56    Private  244605       HS-grad                9
# 28854   45    Private  363677     Doctorate               16
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %%
data.isin(['?']).sum()
# Out:
# age                   0
# workclass          1695
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         1700
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      497
# income                0
# dtype: int64

# %%
data['workclass']=data['workclass'].replace('?',np.nan)

# %%
data.isin(['?']).sum()
# Out:
# age                   0
# workclass             0
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         1700
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      497
# income                0
# dtype: int64

# %%
data['occupation']=data['occupation'].replace('?',np.nan)

# %%
data.isin(['?']).sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# educational-num      0
# marital-status       0
# occupation           0
# relationship         0
# race                 0
# gender               0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     497
# income               0
# dtype: int64

# %%
data['native-country']=data['native-country'].replace('?',np.nan)

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()/len(data)
# Out:
# age                0.0
# workclass          0.0
# fnlwgt             0.0
# education          0.0
# educational-num    0.0
# marital-status     0.0
# occupation         0.0
# relationship       0.0
# race               0.0
# gender             0.0
# capital-gain       0.0
# capital-loss       0.0
# hours-per-week     0.0
# native-country     0.0
# income             0.0
# dtype: float64

# %%
data.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 16

# %%
data.duplicated().any()
# Out:
# True

# %%
data.drop_duplicates()
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 0       25    Private  226802          11th                7
# 1       38    Private   89814       HS-grad                9
# 2       28  Local-gov  336951    Assoc-acdm               12
# 3       44    Private  160323  Some-college               10
# 5       34    Private  198693          10th                6
# ...    ...        ...     ...           ...              ...
# 28849   53  Local-gov  204447       Masters               14
# 28850   25    Private   66935       HS-grad                9
# 28851   20    Private  344278          11th                7
# 28852   29    Private  108574     Assoc-voc               11
# 28853   56    Private  244605       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %%
data.duplicated().any()
# Out:
# True

# %%
data.describe(include='all')
# Out:
#                  age workclass        fnlwgt education  educational-num  \
# count   26688.000000     26688  2.668800e+04     26688     26688.000000
# unique           NaN         7           NaN        16              NaN
# top              NaN   Private           NaN   HS-grad              NaN
# freq             NaN     19605           NaN      8786              NaN
# mean       38.583446       NaN  1.898415e+05       NaN        10.112822
# std        13.252392       NaN  1.053643e+05       NaN         2.545375
# min        17.000000       NaN  1.349200e+04       NaN         1.000000
# 25%        28.000000       NaN  1.173900e+05       NaN         9.000000
# 50%        37.000000       NaN  1.783095e+05       NaN        10.000000
# 75%        47.000000       NaN  2.388055e+05       NaN        13.000000
# max        90.000000       NaN  1.490400e+06       NaN        16.000000
#
#             marital-status    occupation relationship   race gender  \
# ...

# %%
data['education'].value_counts()
# Out:
# HS-grad         8786
# Some-college    5846
# Bachelors       4461
# Masters         1522
# Assoc-voc       1132
# 11th             970
# Assoc-acdm       868
# 10th             725
# 7th-8th          486
# Prof-school      445
# 9th              392
# 12th             320
# Doctorate        301
# 5th-6th          267
# 1st-4th          125
# Preschool         42
# Name: education, dtype: int64

# %%
data['educational-num'].value_counts()
# Out:
# 9     8786
# 10    5846
# 13    4461
# 14    1522
# 11    1132
# 7      970
# 12     868
# 6      725
# 4      486
# 15     445
# 5      392
# 8      320
# 16     301
# 3      267
# 2      125
# 1       42
# Name: educational-num, dtype: int64

# %%
#educationa_num and education are giving same information .so we can drop any one of them.
#capital-gain	capital-loss are having 75% of data are 0 .so drop these columns

# %%
data.drop(['education','capital-gain','capital-loss'],inplace=True,axis=1)

# %%
data['age'].describe()
# Out:
# count    26688.000000
# mean        38.583446
# std         13.252392
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         47.000000
# max         90.000000
# Name: age, dtype: float64

# %%
data['age'].hist()
# Out:
# <Axes: >

# %%
data[data['age'].between(17,48)]
# Out:
#        age  workclass  fnlwgt  educational-num      marital-status  \
# 0       25    Private  226802                7       Never-married
# 1       38    Private   89814                9  Married-civ-spouse
# 2       28  Local-gov  336951               12  Married-civ-spouse
# 3       44    Private  160323               10  Married-civ-spouse
# 5       34    Private  198693                6       Never-married
# ...    ...        ...     ...              ...                 ...
# 28847   44    Private  156413               10  Married-civ-spouse
# 28848   41    Private  116797                9  Married-civ-spouse
# 28850   25    Private   66935                9       Never-married
# 28851   20    Private  344278                7           Separated
# 28852   29    Private  108574               11       Never-married
#
#               occupation   relationship   race  gender  hours-per-week  \
# 0      Machine-op-inspct      Own-child  Black    Male            40.0
# ...

# %%
len(data[data['age'].between(17,48)])
# Out:
# 20622

# %%
data[(data['age']>=17) & (data['age']<=48)]
# Out:
#        age  workclass  fnlwgt  educational-num      marital-status  \
# 0       25    Private  226802                7       Never-married
# 1       38    Private   89814                9  Married-civ-spouse
# 2       28  Local-gov  336951               12  Married-civ-spouse
# 3       44    Private  160323               10  Married-civ-spouse
# 5       34    Private  198693                6       Never-married
# ...    ...        ...     ...              ...                 ...
# 28847   44    Private  156413               10  Married-civ-spouse
# 28848   41    Private  116797                9  Married-civ-spouse
# 28850   25    Private   66935                9       Never-married
# 28851   20    Private  344278                7           Separated
# 28852   29    Private  108574               11       Never-married
#
#               occupation   relationship   race  gender  hours-per-week  \
# 0      Machine-op-inspct      Own-child  Black    Male            40.0
# ...

# %%
plt.figure(figsize=(15,7))
data['workclass'].hist()
# Out:
# <Axes: >

# %%
data['educational-num'].isin([13,14]).sum()
# Out:
# 5983

# %%
data[(data['educational-num']==13) | (data['educational-num']==14)]
# Out:
#        age         workclass  fnlwgt  educational-num      marital-status  \
# 11      36       Federal-gov  212465               13  Married-civ-spouse
# 15      43           Private  346189               14  Married-civ-spouse
# 20      34           Private  107914               13  Married-civ-spouse
# 23      25           Private  220931               13       Never-married
# 24      25           Private  205947               13  Married-civ-spouse
# ...    ...               ...     ...              ...                 ...
# 28835   33           Private  236379               13  Married-civ-spouse
# 28836   46           Private  122026               13  Married-civ-spouse
# 28844   52  Self-emp-not-inc   63004               14  Married-civ-spouse
# 28846   42           Private  211450               14       Never-married
# 28849   53         Local-gov  204447               14  Married-civ-spouse
#
#             occupation   relationship                race gender  \
# ...

# %%
#bivariate analysis

sns.boxplot(x='income',y='age',data=data)
# Out:
# <Axes: xlabel='income', ylabel='age'>

# %%
#Replace Salary Values With 0 and 1

data['income']=data['income'].map({'<=50k':0,'>50k':1})

# %%
data['income']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 5       NaN
#          ..
# 28849   NaN
# 28850   NaN
# 28851   NaN
# 28852   NaN
# 28853   NaN
# Name: income, Length: 26688, dtype: float64

# %%
data
# Out:
#        age  workclass  fnlwgt  educational-num      marital-status  \
# 0       25    Private  226802                7       Never-married
# 1       38    Private   89814                9  Married-civ-spouse
# 2       28  Local-gov  336951               12  Married-civ-spouse
# 3       44    Private  160323               10  Married-civ-spouse
# 5       34    Private  198693                6       Never-married
# ...    ...        ...     ...              ...                 ...
# 28849   53  Local-gov  204447               14  Married-civ-spouse
# 28850   25    Private   66935                9       Never-married
# 28851   20    Private  344278                7           Separated
# 28852   29    Private  108574               11       Never-married
# 28853   56    Private  244605                9  Married-civ-spouse
#
#               occupation   relationship   race  gender  hours-per-week  \
# 0      Machine-op-inspct      Own-child  Black    Male            40.0
# ...

# %%
data3=data2.copy()

# %%
#replace salary with 0 and 1

# %%
data2['income'].value_counts()
# Out:
# <=50K    21999
# >50K      6855
# Name: income, dtype: int64

# %%
data2['income']=data2['income'].replace(['<=50K','>50K'],[0,1])

# %%
data2['income'].value_counts()
# Out:
# 0.0    21999
# 1.0     6855
# Name: income, dtype: int64

# %%
data3['income']=data3['income'].map({'<=50K':0,'>50K':1})

# %%
data3['income'].value_counts()
# Out:
# 0.0    21999
# 1.0     6855
# Name: income, dtype: int64

# %%
#Which Workclass Getting The Highest Salary?
data3.groupby('workclass')['income'].max()
# Out:
# workclass
# ?                   1.0
# Federal-gov         1.0
# Local-gov           1.0
# Never-worked        0.0
# Private             1.0
# Self-emp-inc        1.0
# Self-emp-not-inc    1.0
# State-gov           1.0
# Without-pay         1.0
# Name: income, dtype: float64

# %%
data3.groupby('workclass')['income'].mean().sort_values(ascending=False).head(1)
# Out:
# workclass
# Self-emp-inc    0.548515
# Name: income, dtype: float64

# %%
#who Has Better Chance To Get Salary greater than 50K Male or Female?

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'educational-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
data3.groupby('gender')['income'].mean().sort_values(ascending=False)
# Out:
# gender
# Male      0.300710
# Female    0.110018
# Name: income, dtype: float64

# %%
#Covert workclass Columns Datatype To Category Datatype
data['workclass'].dtype
# Out:
# dtype('O')

# %%
data['workclass']
# Out:
# 0          Private
# 1          Private
# 2        Local-gov
# 3          Private
# 5          Private
#            ...
# 28849    Local-gov
# 28850      Private
# 28851      Private
# 28852      Private
# 28853      Private
# Name: workclass, Length: 26688, dtype: object

# %%
data['new']=data['workclass'].astype('category')

# %%
data['new'].dtype
# Out:
# CategoricalDtype(categories=['Federal-gov', 'Local-gov', 'Private', 'Self-emp-inc',
#                   'Self-emp-not-inc', 'State-gov', 'Without-pay'],
# , ordered=False)
