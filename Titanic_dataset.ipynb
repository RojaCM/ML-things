# %% [markdown]
# <a href="https://colab.research.google.com/github/RojaCM/ML-things/blob/main/Titanic_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Titanic - Machine Learning from Disaster
#
# Dataset Link: https://www.kaggle.com/c/titanic
#
# Features of the dataset:
#
# - survival - Survival (0 = No; 1 = Yes)
# - class - Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
# - name - Name
# - sex - Sex
# - age - Age
# - sibsp - Number of Siblings/Spouses Aboard
# - parch - Number of Parents/Children Aboard
# - ticket - Ticket Number
# - fare - Passenger Fare
# - cabin - Cabin
# - embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)
#
# Questions :
#
#
# 1. Display Top 5 Rows of The Dataset
# 2. Check the Last 3 Rows of The Dataset
# 3. Find Shape of Our Dataset (Number of Rows & Number of Columns)
# 4. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement
# 5. Get Overall Statistics About The Dataframe
# 6. Data Filtering
# 7.Check Null Values In The Dataset
# 8. Drop the Column
# 9. Handle Missing Values
# 10. Categorical Data Encoding

# %%
import pandas as pd

# %%
df=pd.read_csv('train.csv')

# %%
df.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
df[['Sex','Age']]
# Out:
#         Sex   Age
# 0      male  22.0
# 1    female  38.0
# 2    female  26.0
# 3    female  35.0
# 4      male  35.0
# ..      ...   ...
# 886    male  27.0
# 887  female  19.0
# 888  female   NaN
# 889    male  26.0
# 890    male  32.0
#
# [891 rows x 2 columns]

# %%
df[df['Sex']=='male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
sum(df['Sex']=='male')
# Out:
# 577

# %%
sum(df['Survived']==1)
# Out:
# 342

# %%
sum(df['Survived']==1)*100/len(df)
# Out:
# 38.38383838383838

# %%
sum(df['Survived']==0)
# Out:
# 549

# %%
sum(df['Survived']==0)*100/len(df)
# Out:
# 61.61616161616162

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.isnull().sum()*100/len(df)
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
df.drop('Cabin',axis=1,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
df['Embarked'].fillna('S',inplace=True)

# %%
df['Embarked'].isnull().sum()
# Out:
# 0

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Age'].median()
# Out:
# 28.0

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %%
num=df.select_dtypes(exclude='object')

# %%
num
# Out:
#      PassengerId  Survived  Pclass        Age  SibSp  Parch     Fare
# 0              1         0       3  22.000000      1      0   7.2500
# 1              2         1       1  38.000000      1      0  71.2833
# 2              3         1       3  26.000000      0      0   7.9250
# 3              4         1       1  35.000000      1      0  53.1000
# 4              5         0       3  35.000000      0      0   8.0500
# ..           ...       ...     ...        ...    ...    ...      ...
# 886          887         0       2  27.000000      0      0  13.0000
# 887          888         1       1  19.000000      0      0  30.0000
# 888          889         0       3  29.699118      1      2  23.4500
# 889          890         1       1  26.000000      0      0  30.0000
# 890          891         0       3  32.000000      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
cat=df.select_dtypes(include='object')

# %%
cat
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Embarked
# 0           A/5 21171        S
# 1            PC 17599        C
# 2    STON/O2. 3101282        S
# 3              113803        S
# 4              373450        S
# ...

# %%
df.drop('PassengerId',axis=1,inplace=True)

# %%
x=df['Sex'].map({'male':1,'female':0})

# %%
df.insert(4,'Gender_new',x)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex  Gender_new        Age  SibSp  Parch            Ticket     Fare  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l=LabelEncoder()

# %%
df['Embarked'].nunique()
# Out:
# 3

# %%
df['Embarked'].value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
x=pd.get_dummies(df['Embarked'],drop_first=True)

# %%
df1=pd.concat([df,x],axis=1)

# %%
df1
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex  Gender_new        Age  SibSp  Parch            Ticket     Fare  \
# ...

# %%
df1.drop('Embarked',inplace=True,axis=1)

# %%
df1.drop('Sex',axis=1,inplace=True)

# %%
df1['Survived'].hist()
# Out:
# <Axes: >

# %%
sns.countplot(df['Survived'])
# Out:
# <Axes: ylabel='count'>

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
sns.barplot(x='Gender_new',y='Survived',data=df1)
# Out:
# <Axes: xlabel='Gender_new', ylabel='Survived'>

# %%
plt.hist(df['Age'])
# Out:
# (array([ 54.,  46., 177., 346., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fce14ae5910>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fce14ae5e50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fce14ae5670>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fce14af43d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fce14af4670>],
#  'means': []}

# %%
sns.barplot(x='Pclass',y='Survived',data=df1)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
sns.barplot(x='Pclass',y='Survived',data=df1,hue='Gender_new')
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>
